# %% [markdown]
# <a href="https://colab.research.google.com/github/AsifKarimShaik/AsifKarimShaik/blob/main/1_EDA_as_a_group_F23_Asif_Karim_Shaik.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # EDA as a group (Fall 2023)
# ----------------------------------------
# * Dave Wanik - OPIM 5512: Data Science Using Python - University of Connecticut

# %% [markdown]
# **Your Name Here:** Asif Karim Shaik
#
# Groups of four students - give feedback to at least one other person (everyone must receive feedback). First come, first serve!

# %% [markdown]
# The purpose of this assignment is to get you working with the two most common visualization libraries in Python, `matplotlib` (plt) and `seaborn` (sns).
#
# # Rubric
# * Each student will decide to use `matplotlib` or `seabron` or both.
# * (10 pts) Find **FIVE** interesting examples blogs/websites where datasets are cleaned and/or  EDA is completed with `matplotlib` or `sns`. List and describe the sources that you used in a subheader with a short description of the website.
# * (60 pts) Each student will use the dataset that is given to create a total of **TWO** interesting plots (using `matplotlib` or `sns` or a mix). and **ONE** interesting table for each data set ("Incentives by State" and "Efficiency by vehicle".) Each item must have a useful caption with a description of what the output shows and what insights can be derived.
# * (20 pts) Students will post to HuskyCT forum for peer review - thoughtful comments MUST be given (what was good, what could be improved, something new that could be added.) Since this is a dirty dataset, I expect some comments to be about data cleaning!
# * After posting their script for review for peer feedback (as both as shareable link viewable to anyone with the link and as an uploaded file to HuskyCT), students will compare each others code quality and captions (business value of plots and tables) and make a suggestions for improvement.
#
# ## Examples of common feedback items on HuskyCT
# * "I like how you tried four different plots instead of just using one plot over and over again"
# * "That way of cleaning that column was amazing - I'm going to try that on my script too - my way was too manual, yours was way cleaner"
# * "Your caption for Figure 2 could be more clear - maybe say something like this..."
# * "I think it would be interesting to redo Table 2 but group by variable X instead of Z, that way you could get a better understanding of..."
# * "I think you could have made a more thougtful caption for Figure 1 - what is the real value of the plot?"

# %% [markdown]
# ❌ Do not just blindly copy/paste AI-generated code - if I ask you to explain something you submit for credit and you can't do it, you get a 0 for the entire assignment. Make sure you understand what you are doing and come to office hours if you are stuck!

# %% [markdown]
# # Sources
# Here is an example of a good source:
# * [How to Perform Exploratory Data Analysis with Seaborn - Lorraine Lee](https://towardsdatascience.com/how-to-perform-exploratory-data-analysis-with-seaborn-97e3413e841d)
#   * This article was useful because it had a thorough presentation on making plots for categorical and numeric data in seaborn and had lots of 'hackable' code for making subplots.
#
#   You should have five cool sources!

# %% [markdown]
# # Overview

# %% [markdown]
# EVs aren't going away, why not apply what you've learned about EDA to a cool new (dirty) dataset? There are two datasets from Wikipedia for you to check. You will make 3 cool outputs for each dataset, share it with your group (and get feedback!), then you will submit to me.

# %% [markdown]
# ![pacifica](https://di-uploads-pod8.dealerinspire.com/ranchochryslerjeepdodgeram/uploads/2023/03/2023-Chrysler-Pacifica-SilverMist-Cityscape.jpeg)

# %% [markdown]
# ## Read the data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# mute setting with copying warning
pd.options.mode.chained_assignment = None  # default='warn'

# %% [markdown]
# # 🔵 Incentives by State

# %% [markdown]
# Take a look at this table - the primary key actually spans two or three columns - State and Type of PEV/Vehicle. And you already see that it's messy - look at Colarado vs. Connecticut! You will need to recode values using replace values.

# %%
df_state = pd.read_html('https://en.wikipedia.org/wiki/Plug-in_electric_vehicles_in_the_United_States')[1]
df_state
# Out:
#                    State Amount of incentive             Type of PEV/vehicle  \
# 0                Arizona                 NaN                            BEVs
# 1             California        up to $2,500                            BEVs
# 2             California        up to $2,500                           PHEVs
# 3             California        up to $1,500  Electric motorcycles  and NEVs
# 4               Colorado        up to $6,000                  BEVs and PHEVs
# 5            Connecticut        up to $3,000                      BEVs, PHEV
# 6               Delaware        up to $2,200                              EV
# 7   District of Columbia                 NaN                  BEVs and PHEVs
# 8                Florida                 NaN                  BEVs and PHEVs
# 9                Georgia                  $0                            ZEVs
# 10               Georgia        up to $2,500     Alternative fuel conversion
# 11               Georgia       up to $20,000                 Commercial AFVs
# 12                Hawaii                 NaN                  BEVs and PHEVs
# 13                 Idaho                 NaN                      BEVs, PHEV
# 14              Illinois                 NaN     BEVs, PHEVs and conversions
# 15               Indiana        up to $1,650                      BEVs, PHEV
# 16             Louisiana        up to $3,000     BEVs, PHEVs and conversions
# 17              Maryland        up to $3,000                  BEVs and PHEVs
# 18         Massachusetts        up to $1,000                  BEVs and PHEVs
# 19              Michigan                 NaN                      BEVs, PHEV
# 20             Minnesota                 NaN                      BEVs, PHEV
# 21           Mississippi                 NaN                      BEVs, PHEV
# 22              Missouri       up to $15,000                      BEVs, PHEV
# 23               Montana          up to $500     Alternative fuel conversion
# 24              Nebraska                 NaN                      BEVs, PHEV
# 25                Nevada                 NaN                      BEVs, PHEV
# 26         New Hampshire                 NaN                             NaN
# 27            New Jersey         up to $5000                      BEVs, PHEV
# 28              New York                 NaN            BEVs, PHEVs and HEVs
# 29        North Carolina                 NaN                            PHEV
# 30                  Ohio                 NaN                              EV
# 31              Oklahoma            75% cost                             NaN
# 32                Oregon                 NaN                            BEVs
# 33          Pennsylvania        up to $2,000                  BEVs and PHEVs
# 34          Rhode Island                 NaN                            PHEV
# 35        South Carolina        up to $1,500                  BEVs and PHEVs
# 36             Tennessee                 NaN                  BEVs and PHEVs
# 37                 Texas                 NaN                             NaN
# 38                  Utah        up to $1,500                Conversions only
# 39                  Utah        up to $1,500                  BEVs and PHEVs
# 40              Virginia                 NaN                  BEVs and PHEVs
# 41            Washington                 NaN                            BEVs
# 42      Washington, D.C.                 NaN                            BEVs
#
#                                     Type of incentive Carpool lane access  \
# 0                         Lower vehicle licensing tax                 Yes
# 1                                     Purchase rebate                 Yes
# 2                                     Purchase rebate                 Yes
# 3                                     Purchase rebate                 Yes
# 4                                   Income tax credit                  No
# 5                                              Rebate                  No
# 6                                              Rebate                  No
# 7   Excise tax exemption and reduced registration ...                  No
# 8                                                 NaN                 Yes
# 9                                   Income tax credit                 Yes
# 10                                  Income tax credit                 Yes
# 11                                  Income tax credit                 Yes
# 12                                            Parking                 Yes
# 13                               Inspection Exemption                  No
# 14                               Inspection Exemption                  No
# 15                                                NaN                  No
# 16                               Inspection Exemption                  No
# 17                                                NaN             Yes[62]
# 18                                    Purchase rebate                 NaN
# 19                               Inspection exemption                  No
# 20                                                NaN                  No
# 21                                  Income tax credit                  No
# 22                                                NaN                  No
# 23                                  Income tax credit                  No
# 24                                              Loans                  No
# 25                                                NaN                 Yes
# 26                                                NaN                 NaN
# 27              Purchase rebate + sales tax exemption                 Yes
# 28                                                NaN                 Yes
# 29                                                NaN                 Yes
# 30                                                NaN                 Yes
# 31                                  Income tax credit                  No
# 32                                  Income tax credit                  No
# 33                                    Purchase rebate                  No
# 34                               Inspection exemption                  No
# 35                                  Income tax credit                  No
# 36                                             Rebate                 Yes
# 37                                                NaN                  No
# 38                                  Income tax credit                 Yes
# 39                                  Income tax credit                 Yes
# 40                                                NaN                  No
# 41                                          Sales tax                  No
# 42                                          Sales tax                  No
#
#                                              Comments
# 0   Eligibility for PHEVs depends on the extent to...
# 1   Free access to HOVs through January 1, 2019, w...
# 2   PHEV free access to HOV lanes until January 1,...
# 3      All motorcycles have free access to HOV lanes.
# 4   Tax credit totaling 75 to 85% of the cost prem...
# 5   CHEAPR provides up to $3,000 for fuel cell EV,...
# 6   Customers with at a grid-integrated EV may qua...
# 7   A tax credit up to 50% of the equipment costs ...
# 8   Access to HOVs through January 1, 2018 if disp...
# 9   Tax credit of 20% of the cost of a zero emissi...
# 10  Tax credit of 10% of the conversion cost for a...
# 11  Tax credit for new commercial medium-duty or h...
# 12  Carpool lane access and reduced rates for elec...
# 13  EVs are exempt from state motor vehicle inspec...
# 14  Vehicles powered exclusively by electricity ar...
# 15  Credit to install residential charging station...
# 16  Tax credit of 50% of cost premium for BEV/PHEV...
# 17  Plug-in EVs are eligible for an excise tax cre...
# 18  Up to $1,000 rebate for purchasing PEVs, funds...
# 19  Alternative fuel vehicles are exempt from emis...
# 20  All public utilities must file a tariff that a...
# 21  0% interest loans for public school districts ...
# 22  Tax credit for the cost of installing a qualif...
# 23  Credit only available for conversion costs up ...
# 24  Provides low-cost loans for purchase of EVs, t...
# 25  Exempt from emissions testing requirements and...
# 26                                                NaN
# 27  Sales tax exemption for qualifying BEVs only, ...
# 28  Plug-in electric vehicles and hybrid electric ...
# 29  Qualified PEVs are exempt from state emissions...
# 30  Vehicles powered exclusively by electricity, p...
# 31  A tax credit is available for up to 75 percent...
# 32  A tax credit for 25% of charging station costs...
# 33  250 rebates to assist with the purchase of new...
# 34  Vehicles powered exclusively by electricity ar...
# 35  Tax credit equaling 20% of federal credit for ...
# 36                Rebate is limited. HOV lane access.
# 37                       No credits exist as of 2020.
# 38  Credit to convert a vehicle to run on propane,...
# 39                                Until Dec. 31, 2016
# 40  Alternative fuel and hybrid electric vehicles ...
# 41  Beginning on July 1, 2016, a sales tax exempti...
# 42  Vehicles that operate exclusively on electrici...

# %% [markdown]
# I'll help you get started. Looks like we need to combine 'BEVs and PHEVs' and 'BEVs, PHEV'. We can just replace values to make this happen! Then we are ready to go!

# %%
# return unique values in column
df_state['Type of PEV/vehicle'].value_counts()
# Out:
# BEVs and PHEVs                    11
# BEVs, PHEV                        10
# BEVs                               5
# EV                                 2
# Alternative fuel conversion        2
# BEVs, PHEVs and conversions        2
# PHEV                               2
# PHEVs                              1
# Electric motorcycles  and NEVs     1
# ZEVs                               1
# Commercial AFVs                    1
# BEVs, PHEVs and HEVs               1
# Conversions only                   1
# Name: Type of PEV/vehicle, dtype: int64

# %%
# replace value in column
df_state['Type of PEV/vehicle'].replace(['BEVs and PHEVs', 'BEVs, PHEV'], 'BEVs and PHEVs', inplace=True)
# check your work - it worked!
df_state['Type of PEV/vehicle'].value_counts()
# Out:
# BEVs and PHEVs                    21
# BEVs                               5
# EV                                 2
# Alternative fuel conversion        2
# BEVs, PHEVs and conversions        2
# PHEV                               2
# PHEVs                              1
# Electric motorcycles  and NEVs     1
# ZEVs                               1
# Commercial AFVs                    1
# BEVs, PHEVs and HEVs               1
# Conversions only                   1
# Name: Type of PEV/vehicle, dtype: int64

# %% [markdown]
# Use this as inspiration to make three interesting outputs - at least one plot and at least one table.

# %% [markdown]
# ## 🔴 Interesting Output 1

# %%
df_state['Amount of incentive'].value_counts()
# Out:
# up to $1,500     4
# up to $2,500     3
# up to $3,000     3
# up to $6,000     1
# up to $2,200     1
# $0               1
# up to $20,000    1
# up to $1,650     1
# up to $1,000     1
# up to $15,000    1
# up to $500       1
# up to $5000      1
# 75% cost         1
# up to $2,000     1
# Name: Amount of incentive, dtype: int64

# %%
df_state['Amount of incentive'] = df_state['Amount of incentive'].str.replace('up to', ' ')
df_state['Amount of incentive'] = df_state['Amount of incentive'].str.replace(',', '')
df_state['Amount of incentive'] = df_state['Amount of incentive'].str.replace('75% cost', '20000')
df_state['Amount of incentive'] = df_state['Amount of incentive'].str.replace(' ', '')
df_state['Amount of incentive'] = df_state['Amount of incentive'].str.replace('$', '')


# check your work - it worked!
df_state['Amount of incentive'].value_counts()
# Out:
# <ipython-input-155-b2eaeafe1183>:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_state['Amount of incentive'] = df_state['Amount of incentive'].str.replace('$', '')
# 1500     4
# 2500     3
# 3000     3
# 20000    2
# 6000     1
# 2200     1
# 0        1
# 1650     1
# 1000     1
# 15000    1
# 500      1
# 5000     1
# 2000     1
# Name: Amount of incentive, dtype: int64

# %%
df_state['Amount of incentive'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 43 entries, 0 to 42
# Series name: Amount of incentive
# Non-Null Count  Dtype
# --------------  -----
# 21 non-null     object
# dtypes: object(1)
# memory usage: 472.0+ bytes

# %%
df_state['Amount of incentive'] = pd.to_numeric(df_state['Amount of incentive'])
# check your work
df_state['Amount of incentive'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 43 entries, 0 to 42
# Series name: Amount of incentive
# Non-Null Count  Dtype
# --------------  -----
# 21 non-null     float64
# dtypes: float64(1)
# memory usage: 472.0 bytes

# %%
tmp_df = df_state.groupby(['State'])['Amount of incentive'].mean()
tmp_df
# Out:
# State
# Arizona                          NaN
# California               2166.666667
# Colorado                 6000.000000
# Connecticut              3000.000000
# Delaware                 2200.000000
# District of Columbia             NaN
# Florida                          NaN
# Georgia                  7500.000000
# Hawaii                           NaN
# Idaho                            NaN
# Illinois                         NaN
# Indiana                  1650.000000
# Louisiana                3000.000000
# Maryland                 3000.000000
# Massachusetts            1000.000000
# Michigan                         NaN
# Minnesota                        NaN
# Mississippi                      NaN
# Missouri                15000.000000
# Montana                   500.000000
# Nebraska                         NaN
# Nevada                           NaN
# New Hampshire                    NaN
# New Jersey               5000.000000
# New York                         NaN
# North Carolina                   NaN
# Ohio                             NaN
# Oklahoma                20000.000000
# Oregon                           NaN
# Pennsylvania             2000.000000
# Rhode Island                     NaN
# South Carolina           1500.000000
# Tennessee                        NaN
# Texas                            NaN
# Utah                     1500.000000
# Virginia                         NaN
# Washington                       NaN
# Washington, D.C.                 NaN
# Name: Amount of incentive, dtype: float64

# %%
tmp_df = pd.DataFrame(tmp_df)
tmp_df.head()
# Out:
#              Amount of incentive
# State
# Arizona                      NaN
# California           2166.666667
# Colorado             6000.000000
# Connecticut          3000.000000
# Delaware             2200.000000

# %%
tmp_df.hist(column='Amount of incentive', color='red')
plt.xlabel('Amount of Incentive ($)')
plt.show()

# %% [markdown]
# ## 🔴 Interesting Output 2

# %%
# Filter data for BEVs and PHEVs with purchase rebate
bev_and_PHEVs_purchase_rebate = df_state[(df_state['Type of PEV/vehicle'] == 'BEVs and PHEVs') & (df_state['Type of incentive'] == 'Purchase rebate')]

# Sort the data by the amount of incentive in descending order and select the top states
top_states = bev_and_PHEVs_purchase_rebate.sort_values(by='Amount of incentive', ascending=False).head(5)

# Create a bar plot
plt.figure(figsize=(12, 6))
sns.barplot(x='Amount of incentive', y='State', data=top_states, palette='viridis') #using the seeaborn lib as professor suggested
plt.title('Top States with Highest Purchase Rebates for BEVs and PHEVs')
plt.xlabel('Amount of Incentive') #x - label
plt.ylabel('State') #y - label
plt.show()

# %% [markdown]
# ## 🔴 Interesting Output 3

# %% [markdown]
# **Data Summary**

# %%
import pandas as pd

# Display basic info about the dataset
print("Basic Info:")
print(df_state.info())

# Check for missing values
print("\nMissing Values:")
print(df_state.isnull().sum())

# Summary statistics
print("\nSummary Statistics:")
print(df_state.describe())
# Out:
# Basic Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43 entries, 0 to 42
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   State                43 non-null     object
#  1   Amount of incentive  21 non-null     float64
#  2   Type of PEV/vehicle  40 non-null     object
#  3   Type of incentive    31 non-null     object
#  4   Carpool lane access  41 non-null     object
#  5   Comments             42 non-null     object
# dtypes: float64(1), object(5)
# memory usage: 2.1+ KB
# None
#
# Missing Values:
# State                   0
# Amount of incentive    22
# Type of PEV/vehicle     3
# Type of incentive      12
# Carpool lane access     2
# Comments                1
# dtype: int64
#
# Summary Statistics:
#        Amount of incentive
# count            21.000000
# mean           4564.285714
# std            5983.626468
# min               0.000000
# 25%            1500.000000
# 50%            2500.000000
# 75%            3000.000000
# max           20000.000000

# %%
df_tmp = df_state.dropna()

# %%
summary_table = df_tmp.groupby('State').agg({
    'Amount of incentive': 'max',
    'Type of PEV/vehicle': 'count',
    'Carpool lane access': 'first'
}).reset_index()

print("\nSummary Table by State:")
print(summary_table)
# Out:
# Summary Table by State:
#              State  Amount of incentive  Type of PEV/vehicle  \
# 0       California               2500.0                    3
# 1         Colorado               6000.0                    1
# 2      Connecticut               3000.0                    1
# 3         Delaware               2200.0                    1
# 4          Georgia              20000.0                    3
# 5        Louisiana               3000.0                    1
# 6          Montana                500.0                    1
# 7       New Jersey               5000.0                    1
# 8     Pennsylvania               2000.0                    1
# 9   South Carolina               1500.0                    1
# 10            Utah               1500.0                    2
#
#    Carpool lane access
# 0                  Yes
# 1                   No
# 2                   No
# 3                   No
# 4                  Yes
# 5                   No
# 6                   No
# 7                  Yes
# 8                   No
# 9                   No
# 10                 Yes

# %% [markdown]
# # 🔵 Efficiency by vehicle

# %%
df = pd.read_html('https://en.wikipedia.org/wiki/Plug-in_electric_vehicles_in_the_United_States')[4]
df
# Out:
#                                               Vehicle  \
#                                               Vehicle
# 0                    Hyundai Ioniq Electric[106][109]
# 1                             Toyota Prius Prime[111]
# 2                             Toyota Prius Prime[111]
# 3                           BMW i3 (60 A·h)[108][113]
# 4                                    Scion iQ EV[115]
# ..                                                ...
# 80                    Porsche Cayenne S E-Hybrid[170]
# 81                    Porsche Cayenne S E-Hybrid[170]
# 82                               McLaren P1[108][171]
# 83                               McLaren P1[108][171]
# 84  Notes: (1) In November 2010, EPA introduced MP...
#
#                                            Model year  \
#                                            Model year
# 0                                                2017
# 1                                                2017
# 2                                                2017
# 3                                          2014/15/16
# 4                                                2013
# ..                                                ...
# 80                                               2015
# 81                                               2015
# 82                                               2014
# 83                                               2014
# 84  Notes: (1) In November 2010, EPA introduced MP...
#
#                                  Operating mode (AER)  \
#                                  Operating mode (AER)
# 0                               All-electric (124 mi)
# 1                                 Electricity (25 mi)
# 2                                       Gasoline only
# 3                                All-electric (81 mi)
# 4                                All-electric (38 mi)
# ..                                                ...
# 80                   Electricity and gasoline (14 mi)
# 81                                      Gasoline only
# 82                   Electricity and gasoline (19 mi)
# 83                                      Gasoline only
# 84  Notes: (1) In November 2010, EPA introduced MP...
#
#                              EPA fuel economy ratings  \
#                                              Combined
# 0                          136 mpg-e (25 kW·h/100 mi)
# 1                        133 mpg‑e (25.3 kW⋅h/100 mi)
# 2                                              54 mpg
# 3                        124 mpg-e (27 kW-hrs/100 mi)
# 4                        121 mpg-e (28 kW-hrs/100 mi)
# ..                                                ...
# 80                        47 mpg-e (69 kW-hrs/100 mi)
# 81                                             22 mpg
# 82                        18 mpg-e (25 kW-hrs/100 mi)
# 83                                             17 mpg
# 84  Notes: (1) In November 2010, EPA introduced MP...
#
#                                                        \
#                                                  City
# 0                          150 mpg-e (22 kW·h/100 mi)
# 1                                                   -
# 2                                      55 mpg/ 53 mpg
# 3                        137 mpg-e (25 kW-hrs/100 mi)
# 4                        138 mpg-e (24 kW-hrs/100 mi)
# ..                                                ...
# 80                                                  -
# 81                                                  -
# 82                                                  -
# 83                                             16 mpg
# 84  Notes: (1) In November 2010, EPA introduced MP...
#
#                                                        \
#                                               Highway
# 0                          122 mpg-e (28 kW·h/100 mi)
# 1                                                   -
# 2                                                   -
# 3                        111 mpg-e (30 kW-hrs/100 mi)
# 4                        105 mpg-e (32 kW-hrs/100 mi)
# ..                                                ...
# 80                                                  -
# 81                                                  -
# 82                                                  -
# 83                                             20 mpg
# 84  Notes: (1) In November 2010, EPA introduced MP...
#
#                               Cost  to drive 25 miles  \
#                               Cost  to drive 25 miles
# 0                                               $0.81
# 1                                                   -
# 2                                                   -
# 3                                               $0.88
# 4                                               $0.84
# ..                                                ...
# 80                                              $2.07
# 81                                              $4.33
# 82                                              $5.38
# 83                                              $5.60
# 84  Notes: (1) In November 2010, EPA introduced MP...
#
#                       Annual fuel cost(2) (15,000 mi)  \
#                       Annual fuel cost(2) (15,000 mi)
# 0                                                $500
# 1                                                   -
# 2                                                   -
# 3                                                $500
# 4                                                $500
# ..                                                ...
# 80                                             $2,100
# 81                                             $2,100
# 82                                             $3,200
# 83                                             $3,200
# 84  Notes: (1) In November 2010, EPA introduced MP...
#
#                                                 Notes
#                                                 Notes
# 0   The 2017 Hyundai Ioniq Electric is the most fu...
# 1   The 2017 Prius Prime is the most energy-effici...
# 2   The 2017 Prius Prime is the most energy-effici...
# 3   The 2014/15/16 BMW i3 was the most fuel  effic...
# 4   The iQ EV is only available in limited  number...
# ..                                                ...
# 80                                                NaN
# 81                                                NaN
# 82  The P1 does not run on 100% electricity as it ...
# 83  The P1 does not run on 100% electricity as it ...
# 84  Notes: (1) In November 2010, EPA introduced MP...
#
# [85 rows x 9 columns]

# %% [markdown]
# I'll help you get started - real-world data is messy. See the header? See the last row? These will cause problems for you. The multi-index is ANNOYING for selecting the column you want, and the last row is a text cell that repeats for each column. This is a little advanced for new coders, but you have to have good instincts.
#
# * https://towardsdatascience.com/how-to-flatten-multiindex-columns-and-rows-in-pandas-f5406c50e569
# * https://stackoverflow.com/questions/26921651/how-to-delete-the-last-row-of-data-of-a-pandas-dataframe

# %%
# drop the last row
df = df[:-1]

# collapse the multi-index
df.columns = df.columns.get_level_values(0)

# check your work
df.head()
# Out:
#                             Vehicle  Model year   Operating mode (AER)  \
# 0  Hyundai Ioniq Electric[106][109]        2017  All-electric (124 mi)
# 1           Toyota Prius Prime[111]        2017    Electricity (25 mi)
# 2           Toyota Prius Prime[111]        2017          Gasoline only
# 3         BMW i3 (60 A·h)[108][113]  2014/15/16   All-electric (81 mi)
# 4                  Scion iQ EV[115]        2013   All-electric (38 mi)
#
#        EPA fuel economy ratings      EPA fuel economy ratings  \
# 0    136 mpg-e (25 kW·h/100 mi)    150 mpg-e (22 kW·h/100 mi)
# 1  133 mpg‑e (25.3 kW⋅h/100 mi)                             -
# 2                        54 mpg                55 mpg/ 53 mpg
# 3  124 mpg-e (27 kW-hrs/100 mi)  137 mpg-e (25 kW-hrs/100 mi)
# 4  121 mpg-e (28 kW-hrs/100 mi)  138 mpg-e (24 kW-hrs/100 mi)
#
#        EPA fuel economy ratings Cost  to drive 25 miles  \
# 0    122 mpg-e (28 kW·h/100 mi)                   $0.81
# 1                             -                       -
# 2                             -                       -
# 3  111 mpg-e (30 kW-hrs/100 mi)                   $0.88
# 4  105 mpg-e (32 kW-hrs/100 mi)                   $0.84
#
#   Annual fuel cost(2) (15,000 mi)  \
# 0                            $500
# 1                               -
# 2                               -
# 3                            $500
# 4                            $500
#
#                                                Notes
# 0  The 2017 Hyundai Ioniq Electric is the most fu...
# 1  The 2017 Prius Prime is the most energy-effici...
# 2  The 2017 Prius Prime is the most energy-effici...
# 3  The 2014/15/16 BMW i3 was the most fuel  effic...
# 4  The iQ EV is only available in limited  number...

# %% [markdown]
# See how the data is dirty? You need to clean it up! Get rid of special characters like dollar signs, periods, commas and anything else that is annoying! I leave this to you to figure out.

# %%
df.columns
# Out:
# Index(['Vehicle', 'Model year', 'Operating mode (AER)',
#        'EPA fuel economy ratings', 'EPA fuel economy ratings',
#        'EPA fuel economy ratings', 'Cost  to drive 25 miles',
#        'Annual fuel cost(2) (15,000 mi)', 'Notes'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84 entries, 0 to 83
# Data columns (total 9 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Vehicle                          84 non-null     object
#  1   Model year                       84 non-null     object
#  2   Operating mode (AER)             84 non-null     object
#  3   EPA fuel economy ratings         84 non-null     object
#  4   EPA fuel economy ratings         84 non-null     object
#  5   EPA fuel economy ratings         84 non-null     object
#  6   Cost  to drive 25 miles          84 non-null     object
#  7   Annual fuel cost(2) (15,000 mi)  84 non-null     object
#  8   Notes                            59 non-null     object
# dtypes: object(9)
# memory usage: 6.0+ KB

# %% [markdown]
# This one was hard for me too - there was a special character HIDING in this column name!

# %%
# look at how nasty this column name secretly is!
df.columns[7]
# Out:
# 'Annual fuel cost(2) (15,000\xa0mi)'

# %%
# rename the column
df.rename({df.columns[7]  : 'Annual fuel cost'}, axis='columns', inplace=True)
# check your work
df.head()
# Out:
#                             Vehicle  Model year   Operating mode (AER)  \
# 0  Hyundai Ioniq Electric[106][109]        2017  All-electric (124 mi)
# 1           Toyota Prius Prime[111]        2017    Electricity (25 mi)
# 2           Toyota Prius Prime[111]        2017          Gasoline only
# 3         BMW i3 (60 A·h)[108][113]  2014/15/16   All-electric (81 mi)
# 4                  Scion iQ EV[115]        2013   All-electric (38 mi)
#
#        EPA fuel economy ratings      EPA fuel economy ratings  \
# 0    136 mpg-e (25 kW·h/100 mi)    150 mpg-e (22 kW·h/100 mi)
# 1  133 mpg‑e (25.3 kW⋅h/100 mi)                             -
# 2                        54 mpg                55 mpg/ 53 mpg
# 3  124 mpg-e (27 kW-hrs/100 mi)  137 mpg-e (25 kW-hrs/100 mi)
# 4  121 mpg-e (28 kW-hrs/100 mi)  138 mpg-e (24 kW-hrs/100 mi)
#
#        EPA fuel economy ratings Cost  to drive 25 miles Annual fuel cost  \
# 0    122 mpg-e (28 kW·h/100 mi)                   $0.81             $500
# 1                             -                       -                -
# 2                             -                       -                -
# 3  111 mpg-e (30 kW-hrs/100 mi)                   $0.88             $500
# 4  105 mpg-e (32 kW-hrs/100 mi)                   $0.84             $500
#
#                                                Notes
# 0  The 2017 Hyundai Ioniq Electric is the most fu...
# 1  The 2017 Prius Prime is the most energy-effici...
# 2  The 2017 Prius Prime is the most energy-effici...
# 3  The 2014/15/16 BMW i3 was the most fuel  effic...
# 4  The iQ EV is only available in limited  number...

# %%
# remove special characters
df['Annual fuel cost'] = df['Annual fuel cost'].str.replace('$', '')
df['Annual fuel cost'] = df['Annual fuel cost'].str.replace('-', '')
df['Annual fuel cost'] = df['Annual fuel cost'].str.replace(',', '')
df.head()
# Out:
# <ipython-input-171-0b8b2a70f819>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Annual fuel cost'] = df['Annual fuel cost'].str.replace('$', '')
#                             Vehicle  Model year   Operating mode (AER)  \
# 0  Hyundai Ioniq Electric[106][109]        2017  All-electric (124 mi)
# 1           Toyota Prius Prime[111]        2017    Electricity (25 mi)
# 2           Toyota Prius Prime[111]        2017          Gasoline only
# 3         BMW i3 (60 A·h)[108][113]  2014/15/16   All-electric (81 mi)
# 4                  Scion iQ EV[115]        2013   All-electric (38 mi)
#
#        EPA fuel economy ratings      EPA fuel economy ratings  \
# 0    136 mpg-e (25 kW·h/100 mi)    150 mpg-e (22 kW·h/100 mi)
# 1  133 mpg‑e (25.3 kW⋅h/100 mi)                             -
# 2                        54 mpg                55 mpg/ 53 mpg
# 3  124 mpg-e (27 kW-hrs/100 mi)  137 mpg-e (25 kW-hrs/100 mi)
# 4  121 mpg-e (28 kW-hrs/100 mi)  138 mpg-e (24 kW-hrs/100 mi)
#
#        EPA fuel economy ratings Cost  to drive 25 miles Annual fuel cost  \
# 0    122 mpg-e (28 kW·h/100 mi)                   $0.81              500
# 1                             -                       -
# 2                             -                       -
# 3  111 mpg-e (30 kW-hrs/100 mi)                   $0.88              500
# 4  105 mpg-e (32 kW-hrs/100 mi)                   $0.84              500
#
#                                                Notes
# 0  The 2017 Hyundai Ioniq Electric is the most fu...
# 1  The 2017 Prius Prime is the most energy-effici...
# 2  The 2017 Prius Prime is the most energy-effici...
# 3  The 2014/15/16 BMW i3 was the most fuel  effic...
# 4  The iQ EV is only available in limited  number...

# %% [markdown]
# With special characters, the column is hiding as a string - so you can't do math on it! You need to convert in to numeric. And once it's numeric, you can make cool plots and compute summary stats.

# %%
# convert column to numeric
df['Annual fuel cost'] = pd.to_numeric(df['Annual fuel cost'])
df['Annual fuel cost'].hist()
# Out:
# <Axes: >

# %% [markdown]
# I have given you most of the tools you need to be successul! Take your time and try to crack this dataset open. Use AI to help you make even more amazing outputs if you want, but you have to understand what you coded, don't just copy blindly.

# %% [markdown]
# ## 🔴 Interesting Output 4

# %%
df['Model year'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 84 entries, 0 to 83
# Series name: Model year
# Non-Null Count  Dtype
# --------------  -----
# 84 non-null     object
# dtypes: object(1)
# memory usage: 800.0+ bytes

# %%
df['Model year'].value_counts()
# Out:
# 2016                20
# 2017                13
# 2014                 6
# 2015                 6
# 2014/15/16           5
# 2013/14              4
# 2014/15              4
# 2012                 4
# 2011/12              3
# 2012/13/14           3
# 2015/16              2
# 2013/14/15/16        2
# 2013                 2
# 2011                 2
# 2013/16              2
# 2016/17              2
# 2013/14/15           1
# 2012/13/14/16        1
# 2012/13/14/15/16     1
# 2012/13              1
# Name: Model year, dtype: int64

# %%
df['Model year'] =  df['Model year'].str.split('/').str[0]
df.head()
# Out:
#                             Vehicle Model year   Operating mode (AER)  \
# 0  Hyundai Ioniq Electric[106][109]       2017  All-electric (124 mi)
# 1           Toyota Prius Prime[111]       2017    Electricity (25 mi)
# 2           Toyota Prius Prime[111]       2017          Gasoline only
# 3         BMW i3 (60 A·h)[108][113]       2014   All-electric (81 mi)
# 4                  Scion iQ EV[115]       2013   All-electric (38 mi)
#
#        EPA fuel economy ratings      EPA fuel economy ratings  \
# 0    136 mpg-e (25 kW·h/100 mi)    150 mpg-e (22 kW·h/100 mi)
# 1  133 mpg‑e (25.3 kW⋅h/100 mi)                             -
# 2                        54 mpg                55 mpg/ 53 mpg
# 3  124 mpg-e (27 kW-hrs/100 mi)  137 mpg-e (25 kW-hrs/100 mi)
# 4  121 mpg-e (28 kW-hrs/100 mi)  138 mpg-e (24 kW-hrs/100 mi)
#
#        EPA fuel economy ratings Cost  to drive 25 miles  Annual fuel cost  \
# 0    122 mpg-e (28 kW·h/100 mi)                   $0.81             500.0
# 1                             -                       -               NaN
# 2                             -                       -               NaN
# 3  111 mpg-e (30 kW-hrs/100 mi)                   $0.88             500.0
# 4  105 mpg-e (32 kW-hrs/100 mi)                   $0.84             500.0
#
#                                                Notes
# 0  The 2017 Hyundai Ioniq Electric is the most fu...
# 1  The 2017 Prius Prime is the most energy-effici...
# 2  The 2017 Prius Prime is the most energy-effici...
# 3  The 2014/15/16 BMW i3 was the most fuel  effic...
# 4  The iQ EV is only available in limited  number...

# %%
df['Model year'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 84 entries, 0 to 83
# Series name: Model year
# Non-Null Count  Dtype
# --------------  -----
# 84 non-null     object
# dtypes: object(1)
# memory usage: 800.0+ bytes

# %%
df['Model year'] = pd.to_numeric(df['Model year'])

# %%
print(df.shape)
df = df[(df['Model year'] >= 2011) & (df['Model year'] <= 2014)]
print(df.shape)
# Out:
# (84, 9)
# (41, 9)

# %%
tmp = df.groupby(['Model year'])['Model year'].count()
tmp
# Out:
# Model year
# 2011     5
# 2012    10
# 2013    11
# 2014    15
# Name: Model year, dtype: int64

# %%
tmp = pd.DataFrame(tmp)
tmp.head()
# Out:
#             Model year
# Model year
# 2011                 5
# 2012                10
# 2013                11
# 2014                15

# %%
tmp.rename({'Model year': 'Count'}, axis=1, inplace=True)
tmp.head()
# Out:
#             Count
# Model year
# 2011            5
# 2012           10
# 2013           11
# 2014           15

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming you have a DataFrame 'df' with a 'Year' column
sns.set(style="darkgrid")  # Set the style of the plot

# Create a count plot
sns.countplot(x='Model year', data=df)

# Rotate x-axis labels for better readability (optional)
plt.xticks(rotation=45)

# Set labels and title
plt.xlabel('Model Year')
plt.ylabel('Count')
plt.title('Count')

# Show the plot
plt.show()

# %%
df
# Out:
#                                               Vehicle  Model year  \
# 3                           BMW i3 (60 A·h)[108][113]        2014
# 4                                    Scion iQ EV[115]        2013
# 6                             Chevrolet Spark EV[120]        2014
# 8                                   Honda Fit EV[122]        2013
# 9                       BMW i3 REx (60 A·h)[108][123]        2014
# 10                      BMW i3 REx (60 A·h)[108][123]        2014
# 12                                     Fiat 500e[128]        2013
# 13                        Nissan Leaf (24 kW-hr)[129]        2013
# 14                             Honda Accord PHEV[130]        2014
# 15                             Honda Accord PHEV[130]        2014
# 17                                  Mitsubishi i[132]        2012
# 21                          Smart electric drive[134]        2013
# 25                           Ford Focus Electric[139]        2012
# 26                                   BMW ActiveE[140]        2011
# 27                                   Nissan Leaf[141]        2011
# 30                                Chevrolet Volt[143]        2013
# 31                                Chevrolet Volt[143]        2013
# 34                            Tesla Model S[108][145]        2013
# 35                              Toyota Prius PHV[146]        2012
# 36                              Toyota Prius PHV[146]        2012
# 37                                Chevrolet Volt[147]        2011
# 38                                Chevrolet Volt[147]        2011
# 39                                 Tesla Model S[148]        2013
# 42                                 Tesla Model S[145]        2012
# 43  Ford C-Max Energi[151][152] Ford Fusion Energi...        2013
# 44  Ford C-Max Energi[151][152] Ford Fusion Energi...        2013
# 45                          Smart electric drive[134]        2011
# 50     Mercedes-Benz B-Class Electric Drive[108][155]        2014
# 55                                  Cadillac ELR[157]        2014
# 56                                  Cadillac ELR[157]        2014
# 59                           Toyota RAV4 EV[108][158]        2012
# 60                                   BMW i8[108][159]        2014
# 61                                   BMW i8[108][159]        2014
# 62                                          Coda[160]        2012
# 67                                        BYD e6[163]        2012
# 74                                  Fisker Karma[167]        2012
# 75                                  Fisker Karma[167]        2012
# 78                   Porsche Panamera S E-Hybrid[169]        2014
# 79                   Porsche Panamera S E-Hybrid[169]        2014
# 82                               McLaren P1[108][171]        2014
# 83                               McLaren P1[108][171]        2014
#
#                  Operating mode (AER)  \
# 3                All-electric (81 mi)
# 4                All-electric (38 mi)
# 6                All-electric (82 mi)
# 8                All-electric (82 mi)
# 9            Electricity only (72 mi)
# 10              Gasoline only (78 mi)
# 12               All-electric (87 mi)
# 13               All-electric (84 mi)
# 14   Electricity and gasoline (13 mi)
# 15                      Gasoline only
# 17               All-electric (62 mi)
# 21               All-electric (68 mi)
# 25               All-electric (76 mi)
# 26               All-electric (94 mi)
# 27               All-electric (73 mi)
# 30           Electricity only (38 mi)
# 31                      Gasoline only
# 34              All-electric (208 mi)
# 35   Electricity and gasoline (11 mi)
# 36                      Gasoline only
# 37           Electricity only (35 mi)
# 38                      Gasoline only
# 39              All-electric (139 mi)
# 42              All-electric (265 mi)
# 43   Electricity and gasoline (20 mi)
# 44                      Gasoline only
# 45               All-electric (63 mi)
# 50               All-electric (87 mi)
# 55           Electricity only (37 mi)
# 56                      Gasoline only
# 59              All-electric (103 mi)
# 60  Electricity and  gasoline (15 mi)
# 61                      Gasoline only
# 62               All-electric (88 mi)
# 67              All-electric (122 mi)
# 74           Electricity only (33 mi)
# 75                      Gasoline only
# 78   Electricity and gasoline (16 mi)
# 79                      Gasoline only
# 82   Electricity and gasoline (19 mi)
# 83                      Gasoline only
#
#                              EPA fuel economy ratings  \
# 3                        124 mpg-e (27 kW-hrs/100 mi)
# 4                        121 mpg-e (28 kW-hrs/100 mi)
# 6                        119 mpg-e (28 kW-hrs/100 mi)
# 8                        118 mpg-e (29 kW-hrs/100 mi)
# 9                        117 mpg-e (29 kW-hrs/100 mi)
# 10                                             39 mpg
# 12                       116 mpg-e (29 kW-hrs/100 mi)
# 13                       114 mpg-e (30 kW-hrs/100 mi)
# 14                       115 mpg-e (29 kW-hrs/100 mi)
# 15                                             46 mpg
# 17                       112 mpg-e (30 kW-hrs/100 mi)
# 21                       107 mpg-e (32 kW-hrs/100 mi)
# 25                       105 mpg-e (32 kW-hrs/100 mi)
# 26                       102 mpg-e (33 kW-hrs/100 mi)
# 27                        99 mpg-e (34 kW-hrs/100 mi)
# 30                        98 mpg-e (35 kW-hrs/100 mi)
# 31                                             37 mpg
# 34                        95 mpg-e (35 kW-hrs/100 mi)
# 35  95 mpg-e (29 kW-hrs/100 mi  plus 0.2 gallons/1...
# 36                                             50 mpg
# 37                        94 mpg-e (36 kW-hrs/100 mi)
# 38                                             37 mpg
# 39                        94 mpg-e (36 kW-hrs/100 mi)
# 42                        89 mpg-e (38 kW-hrs/100 mi)
# 43                        88 mpg-e (37 kW-hrs/100 mi)
# 44                                             38 mpg
# 45                        87 mpg-e (39 kW-hrs/100 mi)
# 50                        84 mpg-e (40 kW-hrs/100 mi)
# 55                        82 mpg-e (41 kW-hrs/100 mi)
# 56                                             33 mpg
# 59                        76 mpg-e (44 kW-hrs/100 mi)
# 60                        76 mpg-e (43 kW-hrs/100 mi)
# 61                                             28 mpg
# 62                        73 mpg-e (46 kW-hrs/100 mi)
# 67                        62 mpg-e (54 kW-hrs/100 mi)
# 74                        54 mpg-e (62 kW-hrs/100 mi)
# 75                                             20 mpg
# 78                        50 mpg-e (52 kW-hrs/100 mi)
# 79                                             25 mpg
# 82                        18 mpg-e (25 kW-hrs/100 mi)
# 83                                             17 mpg
#
#         EPA fuel economy ratings      EPA fuel economy ratings  \
# 3   137 mpg-e (25 kW-hrs/100 mi)  111 mpg-e (30 kW-hrs/100 mi)
# 4   138 mpg-e (24 kW-hrs/100 mi)  105 mpg-e (32 kW-hrs/100 mi)
# 6   121 mpg-e (28 kW-hrs/100 mi)  138 mpg-e (24 kW-hrs/100 mi)
# 8   132 mpg-e (26 kW-hrs/100 mi)  105 mpg-e (32 kW-hrs/100 mi)
# 9      97 mpg‑e (35 kW⋅h/100 mi)     79 mpg‑e (43 kW⋅h/100 mi)
# 10                        41 mpg                        37 mpg
# 12  122 mpg-e (28 kW-hrs/100 mi)  108 mpg-e (31 kW-hrs/100 mi)
# 13  126 mpg-e (27 kW-hrs/100 mi)  101 mpg-e (33 kW-hrs/100 mi)
# 14                             -                             -
# 15                        47 mpg                        46 mpg
# 17  126 mpg-e (27 kW-hrs/100 mi)   99 mpg-e (34 kW-hrs/100 mi)
# 21  122 mpg-e (28 kW-hrs/100 mi)   93 mpg-e (36 kW-hrs/100 mi)
# 25  110 mpg-e (31 kW-hrs/100 mi)   99 mpg-e (34 kW-hrs/100 mi)
# 26    107 mpg‑e (31 kW⋅h/100 mi)     96 mpg‑e (35 kW⋅h/100 mi)
# 27  106 mpg-e (32 kW-hrs/100 mi)   92 mpg-e (37 kW-hrs/100 mi)
# 30                             -                             -
# 31                        35 mpg                        40 mpg
# 34   94 mpg-e (36 kW-hrs/100 mi)   97 mpg-e (35 kW-hrs/100 mi)
# 35                             -                             -
# 36                        51 mpg                        49 mpg
# 37   95 mpg-e (36 kW-hrs/100 mi)   93 mpg-e (37 kW-hrs/100 mi)
# 38                        35 mpg                        40 mpg
# 39     93 mpg‑e (36 kW⋅h/100 mi)     96 mpg‑e (35 kW⋅h/100 mi)
# 42   88 mpg-e (38 kW-hrs/100 mi)   90 mpg-e (37 kW-hrs/100 mi)
# 43     95 mpg‑e (35 kW⋅h/100 mi)     81 mpg‑e (42 kW⋅h/100 mi)
# 44                        40 mpg                        36 mpg
# 45     94 mpg‑e (36 kW⋅h/100 mi)     79 mpg‑e (43 kW⋅h/100 mi)
# 50   85 mpg-e (40 kW-hrs/100 mi)   83 mpg-e (41 kW-hrs/100 mi)
# 55                             -                             -
# 56                        31 mpg                        35 mpg
# 59   78 mpg-e (43 kW-hrs/100 mi)   74 mpg-e (46 kW-hrs/100 mi)
# 60                             -                             -
# 61                        28 mpg                        29 mpg
# 62   77 mpg-e (44 kW-hrs/100 mi)   68 mpg-e (50 kW-hrs/100 mi)
# 67   60 mpg-e (56 kW-hrs/100 mi)   64 mpg-e (52 kW-hrs/100 mi)
# 74                             -                             -
# 75                        20 mpg                        21 mpg
# 78                             -                             -
# 79                        23 mpg                        29 mpg
# 82                             -                             -
# 83                        16 mpg                        20 mpg
#
#    Cost  to drive 25 miles  Annual fuel cost  \
# 3                    $0.88             500.0
# 4                    $0.84             500.0
# 6                    $0.92             550.0
# 8                    $0.94             550.0
# 9                    $0.94             650.0
# 10                   $1.77             650.0
# 12                   $0.88             550.0
# 13                   $0.89             550.0
# 14                   $1.36             950.0
# 15                   $1.36             950.0
# 17                   $0.90             550.0
# 21                   $0.96             600.0
# 25                   $0.96             600.0
# 26                   $0.99             600.0
# 27                   $1.02             600.0
# 30                   $1.14             800.0
# 31                   $1.86             800.0
# 34                   $1.05             650.0
# 35                   $1.43             900.0
# 36                   $1.74             900.0
# 37                   $1.08            1000.0
# 38                   $2.57            1000.0
# 39                   $1.08             650.0
# 42                   $1.14             700.0
# 43                   $1.36            1050.0
# 44                   $2.29            1050.0
# 45                   $1.17             700.0
# 50                   $1.20             700.0
# 55                   $1.23            1100.0
# 56                   $2.89            1100.0
# 59                   $1.32             800.0
# 60                   $2.19            1550.0
# 61                   $3.40            1550.0
# 62                   $1.38             850.0
# 67                   $1.62             950.0
# 74                   $1.86            1750.0
# 75                   $4.76            1750.0
# 78                   $3.49            1850.0
# 79                   $3.81            1850.0
# 82                   $5.38            3200.0
# 83                   $5.60            3200.0
#
#                                                 Notes
# 3   The 2014/15/16 BMW i3 was the most fuel  effic...
# 4   The iQ EV is only available in limited  number...
# 6                                                 NaN
# 8                                                 NaN
# 9   The EPA classifies the i3 REx as a series plug...
# 10  The EPA classifies the i3 REx as a series plug...
# 12                                                NaN
# 13  The 2016 model year Leaf correspond to the var...
# 14  The first 13 mi it has a combined rating  of 1...
# 15  The first 13 mi it has a combined rating  of 1...
# 17                                                NaN
# 21  Third generation model. Ratings and costs are ...
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 30  The 2013/14 Volt has a combined gasoline/elect...
# 31  The 2013/14 Volt has a combined gasoline/elect...
# 34                     Model with 60 kWh battery pack
# 35  After the first 11 mi the car  functions like ...
# 36  After the first 11 mi the car  functions like ...
# 37  Both model year 2011 and 2012 have the same op...
# 38  Both model year 2011 and 2012 have the same op...
# 39  Model with 40 kWh battery pack.  This model wa...
# 42                      Model with 85kWh battery pack
# 43  The Energi did not use any gasoline  for the f...
# 44  The Energi did not use any gasoline  for the f...
# 45  Second generation model. Ratings are costs for...
# 50                                                NaN
# 55  The 2014 ELR has a combined  EV/gasoline ratin...
# 56  The 2014 ELR has a combined  EV/gasoline ratin...
# 59                                                NaN
# 60  The i8 does not run on 100% electricity as it ...
# 61  The i8 does not run on 100% electricity as it ...
# 62                                                NaN
# 67                                                NaN
# 74                                                NaN
# 75                                                NaN
# 78  The all-electric range is between  0 to 15 mi....
# 79  The all-electric range is between  0 to 15 mi....
# 82  The P1 does not run on 100% electricity as it ...
# 83  The P1 does not run on 100% electricity as it ...

# %% [markdown]
# Creating a summary table

# %%
summary_table = df.groupby('Model year').agg({
    'Vehicle': 'count',
    'Annual fuel cost': 'mean'
}).reset_index() #grouping the df by model year and using aggregation ops

print("\nSummary Table by Vehicle Model Year:")
print(summary_table)
# Out:
# Summary Table by Vehicle Model Year:
#    Model year  Vehicle  Annual fuel cost
# 0        2011        5        780.000000
# 1        2012       10        975.000000
# 2        2013       11        704.545455
# 3        2014       15       1356.666667

# %% [markdown]
# ## 🔴 Interesting Output 5

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Annual fuel cost'], bins=20, kde=True)
plt.title('Distribution of Annual Fuel Costs')
plt.xlabel('Annual Fuel Cost ($)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## 🔴 Interesting Output 6

# %%
# Create a scatter plot
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Model year', y='Annual fuel cost', data=df, hue='Model year', palette='coolwarm') #scatterplot with 'Model Year' on X axis and 'Annual fuel Cost' on Y axis
plt.xlabel('Model Year')
plt.ylabel('Annual Fuel Cost ($)')
plt.title('Model Year vs Annual Fuel Cost')
plt.legend(loc='upper right', title='Model Year') #adding a legend to upper right corner
plt.show()

# %% [markdown]
# #REFERENCES
#
# *   https://www.kaggle.com/code/pmarcelino/comprehensive-data-exploration-with-python
#
# This article was very much helful to shine up my pandas and seaborn skills. I have a little bit of knowledge in these libraries.
#
#
# *   https://www.kaggle.com/code/saurav9786/matplot-tutorial-for-everyone
#
# This article from kaggle helped me to get the plotting skills. It has all the tutorials related to line, barr, histograms and various types of graphs.
#
#
#
# *   https://www.kaggle.com/code/lavanyashukla01/pandas-numpy-python-cheatsheet
#
# Used this cheatsheet to go through some commands on accessing and modifying the elements.
#
#
#
# *   https://www.kaggle.com/code/mafaisal007/data-wrangling-tutorial
#
# Many references were used in my work. Of all the above ones, this is my favorite as this article have homework questions in it, which can be very helpful while practising.
#
#
# *   https://www.analyticsvidhya.com/blog/2020/03/10-awesome-data-manipulation-and-wrangling-hacks-tips-and-tricks/
#
# This artilce redirects us to watch the youtube videos, which are very well explained.
